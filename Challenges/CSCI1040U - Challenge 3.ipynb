# %% [markdown]
# # Coding Challenge 3 #
#
# Due date: **March 16th (11:59 PM)**
#
# - This is an **individual** assignment.
# - Do **NOT** copy from others, do **NOT** post the assignment instructions, and do **NOT** share your answer with others.
# - Remember, copying and pasting from any other person or online resources is also considered **plagiarism**.
# - Any form of plagiarism will be treated accordingly to the university's code of conduct.
#
# The goal of this assignment is to measure learning milestones.
#
# Can you effectively apply basic programming concepts such as: variables, conditionals, loops, sequences, and functions?
#
# To help students improve on their logical thinking, the grading will consider not only if the solution produces the correct output, but also the balance between efficiency and readability of the coding.
#
# - You are required to document your code using comments. *Failing to do so may result on deductions.*
# - You are required to submit both version (PDF and ipynb) of your solution. *Failing to do so may result on deductions.*

# %%
# Challenge 3 - CSCI1040U
# Student name
# Student ID
# Date

# %% [markdown]
# **General Tips/Strategies**
# - Refer to the course material and the practice questions for similar problems.
# - Before you start, make sure you understand the problem first, then start thinking about the solution.
# - Focus on each of the enumerated tasks/steps at a time.
# - Use comments to guide yourself on steps you need to take -- so you don't forget, also gives you a clearer picture of what to do.
#
# ## The Challenge ##
#
# **Background:** The province of Ontario has released their plan of COVID-19 vaccinations.
#
# The vaccine will be given in 2 shots.
#
# At the moment any Ontario resident can take the vaccine, if he/she:
#
#     1. is 80 years or older, or
#     2. is a health worker.
# Also, he/she does not have underlying conditions.
#
# *Disclosure: this is a fictional scenario only, and not the actual Ontario eligibility rules*
#
#
# This challenge has 2 parts:
#
# ### Part 1 ###
# **Vaccine Eligibility**
#
# Write a Python **function** `isEligible` that validates someone's elligibility for the vaccine.
#
# Your function should:
# 1. Receive 3 arguments:
#     - `age`: an int value with the persons age
#     - `healthWorker`:a Boolean value, True if they are a health worker, or False if they are not
#     - `otherCondition`:a Boolean value, True if they have any underlying conditions, or False if they do not
# 2. Check for the eligibility of the person based on the rules described above.
# 3. Returns a Boolean value
#     - `True`: if the person is eligible
#     - `False`: if the person is *not* eligible
#
# Also, please provide 5 extra test cases like the ones shown:

# %%
# your solution here



# ------
# test cases - uncomment to run after implementing the function

# print(isEligible(54, False, False)) #expected output False
# print(isEligible(34, True, False)) #expected output True
# print(isEligible(80, False, False)) #expected output True
# print(isEligible(81, True, False)) #expected output True
# print(isEligible(87, False, True)) #expected output False
# ------
# Your test cases here

# %% [markdown]
# ### Part 2 ###
#
# **Vaccination**
#
# Write a Python **function** `vaccinate`
#
# Your function should:
# 1. Receive 2 lists:
#     - `patients`: list of strings containing the patient's name
#     - `nShots`: list of int values containing each of the respective patient's number of shots already received
# 2. Check if the arguments are valid:
#     - Arguments are valid if the number of elements in `patients` has the same as the number of elements in `nShots`
#     - If the arguments are invalid: print a message "ERROR:The arguments' length do not match."
#     - If the arguments valid: continue to **step 3**
# 3. Iterate over the patients and their respective number of shots. For each:
#     - If the patient has 0 shots, display a message "PatientName was given their first shot."
#     - If the patient has 1 shots, display a message "PatientName was given their second shot, and is now fully vaccinated."
#     - If the patient has 2 shots, display a message "PatientName has already been vaccinated."
#     - If the patient has any other number of shots, display a message "PatientName's data is corrupted."
#
# Note that, your function does not return any value, but it prints those messages inside instead.
#
# Also, please provide 5 extra test cases like the ones shown:

# %%
# your solution here



# ------
# test cases: uncomment to run after implementing the function

# vaccinate(["Adam", "Eve"],[0,1]) 
# # expected output
# # Adam was given their first shot
# # Eve was given their second shot, and is now fully vaccinated

# vaccinate(["Rose", "Jack"],[5,1]) 
# # expected output
# # Rose's data is corrupted
# # Jack was given their second shot, and is now fully vaccinated

# vaccinate(["John Snow", "Bran Stark", "James Lanister"],[0,0]) 
# # expected output
# # ERROR:The arguments' length do not match.

# vaccinate(["John Snow", "Bran Stark", "James Lanister"],[0,0,1]) 
# # expected output
# # John Snow was given their first shot
# # Bran Stark was given their first shot
# # James Lanister was given their second shot, and is now fully vaccinated

# vaccinate(["John Snow", "Bran Stark", "James Lanister"],[1,1,2]) 
# # expected output
# # John Snow was given their second shot, and is now fully vaccinated
# # Bran Stark was given their second shot, and is now fully vaccinated
# # James Lanister has already been vaccinated


# ------
# Your test cases here

# %% [markdown]
# ### Submission
# Via Canvas, under `Assignments/Challenges/Challenge 3`
# - Submit both `.pdf` and `.ipynb` versions of your notebook with the solution
#
# *Late submissions.* Up to 3 days, 10% deduction per day.

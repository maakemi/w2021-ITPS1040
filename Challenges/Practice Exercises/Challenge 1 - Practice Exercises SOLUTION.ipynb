# %% [markdown]
# # Coding Challenge 1 (Practice only) #
#
# Due date: **none - practice only**
#
# The goal of this assignment is to measure learning milestones.
#
# Can you effectively apply basic programming concepts such as: variables, and conditionals?
#
# **Documentation is obligatory.** Document your code by commenting the steps taken, it should be enough for someone else to undertand your rationale.

# %%
# Challenge - CSCI1040U
# @author your name
# student ID
# Date

# %% [markdown]
# ## The (practice1) challenge
#
# - Write code to check whether a triangle is Equilateral, Isosceles or Scalene.
#
# **Equilateral triangle:** An equilateral triangle is a triangle in which *all three sides are equal*.
#
# **Isosceles triangle:** An isosceles triangle is a triangle that has *two equal sides*.
#
# **Scalene triangle:** A scalene triangle is a triangle that has *three unequal sides*.
#
# - Example output:
# ```
# Input side1: 50
# Input side2: 50
# Input side3: 60
# This is an isosceles triangle.
# ```

# %%
# Reading the triangle sides from the user
side1 = int(input("Input side1:"))
side2 = int(input("Input side2:"))
side3 = int(input("Input side3:"))

# My solution starts here --------
# ------------------------------
# I'm checking on the triangle type based on the given conditions and printing at the same time

    # Equilateral triangle: An equilateral triangle is a triangle in which all three sides are equal.
if (side1==side2 and side3==side2): 
    print("This is an equilateral triangle")
#note I don't need to test side1==side3 because 
# if side1==side2 AND side2==side3, then side1 has to be equals to side 3 as well
    # Isosceles triangle: An isosceles triangle is a triangle that has two equal sides.
elif(side1==side2 or side2==side3 or side1==side3):
    print("This is an isosceles triangle")
else: #none of the sides are equal
    print("This is an scalene triangle")
# Out:
# Input side1: 50
# Input side2: 50
# Input side3: 60
# This is an isosceles triangle

# %% [markdown]
# **Testing your solution - Test Cases**
#
# An advice to make sure your solution is working for all cases, imagine the possible combinations of input and try it out to make sure you are always obtaining the expected result.
#
# For example, some of the test I did with my code:
# - Trying all the combinations of the sides but still isosceles triangles.
#     ```
#     Input side1: 60
#     Input side2: 50
#     Input side3: 50
#     This is an isosceles triangle
#
#     Input side1: 50
#     Input side2: 60
#     Input side3: 50
#     This is an isosceles triangle
#
#     Input side1: 60
#     Input side2: 50
#     Input side3: 50
#     This is an isosceles triangle
#     ```
# - Trying a combination for scalene triangles
#     ```
#     Input side1: 20
#     Input side2: 30
#     Input side3: 10
#     This is an scalene triangle
#     ```
#
# - Trying a combination for equilateral triangle
#
#     ```
#     Input side1: 50
#     Input side2: 50
#     Input side3: 50
#     This is an equilateral triangle
#
#     ```

# %% [markdown]
# ## The (practice2) challenge
#
# Write code that:
# - After reading the information on a student, prints the student's `Grade Report` following the format:
#     ```
#     Student ID: | Student Name: | Total Marks: | Percentage: % | Division:
#     Subject1:
#     Subject2:
#     Subject3:
#     ```
#     - An example output:
#      ```
#     Student ID: 100000000 | Student Name: Arya Stark | Total Marks: 240| Percentage: 80% | Division: First
#     Subject1: 70
#     Subject2: 80
#     Subject3: 90
#     ```
#     where,
#         - Total Marks is the sum of all 3 subjects' grades
#         - Percentage is calculate between the possible total makrs and the student's total marks
#         - Division depends on the category the percentage is found:
#             ```
#             First  | 100 to 60
#             Second | less than 60 to 48
#             Pass   | less than 48 to 36
#             Fail   | less than 36
#             ```

# %%
# Reading the student's information via user input
studentID = int(input("Input the student ID:"))
studentName = str(input("Input the student's name:"))
subj1 = float(input("Input the student's grade for subject1:"))
subj2 = float(input("Input the student's grade for subject2:"))
subj3 = float(input("Input the student's grade for subject3:"))

# My solution starts here --------
# ------------------------------
# Calculate total marks, percentage, and division
totalMarks = subj1 + subj2 + subj3
percentage = (totalMarks/300)*100
# categorizing the devision based on the percentage
if percentage>=60:
    division = "First"
elif percentage>=48:
    division = "Second"
elif percentage>=36:
    division = "Pass"
else:
    division = "Fail"
    
# Print the report using the given template
print("Student ID: ",studentID," | Student Name: ",studentName," | Total Marks: ",totalMarks," | Percentage: ",percentage,"% | Division: ",division)
print("Subject1: ",subj1)
print("Subject2: ",subj2)
print("Subject3: ",subj3)
# Out:
# Input the student ID: 123456789
# Input the student's name: Rob Stark
# Input the student's grade for subject1: 45
# Input the student's grade for subject2: 40
# Input the student's grade for subject3: 43
# Student ID:  123456789  | Student Name:  Rob Stark  | Total Marks:  128.0  | Percentage:  42.66666666666667 % | Division:  Pass
# Subject1:  45.0
# Subject2:  40.0
# Subject3:  43.0

# %% [markdown]
# **Test Cases**
#
# - First division students:
#
#     ```
#     Input the student ID: 123456789
#     Input the student's name: John Doe
#     Input the student's grade for subject1: 50
#     Input the student's grade for subject2: 100
#     Input the student's grade for subject3: 100
#     Student ID:  123456789  | Student Name:  John Doe  | Total Marks:  250.0  | Percentage:  83.33333333333334 % | Division:  First
#     Subject1:  50.0
#     Subject2:  100.0
#     Subject3:  100.0
#
#     Input the student ID: 100000000
#     Input the student's name: Arya Stark
#     Input the student's grade for subject1: 70
#     Input the student's grade for subject2: 80
#     Input the student's grade for subject3: 90
#     Student ID:  100000000  | Student Name:  Arya Stark  | Total Marks:  240.0  | Percentage:  80.0 % | Division:  First
#     Subject1:  70.0
#     Subject2:  80.0
#     Subject3:  90.0
#     ```
#
#
# - Second division student
#
#     ```
#     Input the student ID: 123456789
#     Input the student's name: Bran Stark
#     Input the student's grade for subject1: 50
#     Input the student's grade for subject2: 50
#     Input the student's grade for subject3: 50
#     Student ID:  123456789  | Student Name:  Bran Stark  | Total Marks:  150.0  | Percentage:  50.0 % | Division:  Second
#     Subject1:  50.0
#     Subject2:  50.0
#     Subject3:  50.0
#     ```
#
#
# - Pass division student
#
#     ```
#     Input the student ID: 123456789
#     Input the student's name: Rob Stark
#     Input the student's grade for subject1: 45
#     Input the student's grade for subject2: 40
#     Input the student's grade for subject3: 43
#     Student ID:  123456789  | Student Name:  Rob Stark  | Total Marks:  128.0  | Percentage:  42.66666666666667 % | Division:  Pass
#     Subject1:  45.0
#     Subject2:  40.0
#     Subject3:  43.0
#     ```
#
#
# - Fail division student
#
#     ```
#     Input the student ID: 100000000
#     Input the student's name: John Snow
#     Input the student's grade for subject1: 20
#     Input the student's grade for subject2: 30
#     Input the student's grade for subject3: 40
#     Student ID:  100000000  | Student Name:  John Snow  | Total Marks:  90.0  | Percentage:  30.0 % | Division:  Fail
#     Subject1:  20.0
#     Subject2:  30.0
#     Subject3:  40.0
#     ```

# %% [markdown]
# ## The (practice3) challenge
#
# - Write code to calculate the tax paid by a worker with an given salary.
#
# Assume the tax brackets are:
# ```
# Salary                  | Tax %
# less or equals to 30k   | 15
# less or equals to 60k   | 20
# less or equals to 100k  | 35
# less or equals to 130k  | 40
# more than 130k          | 48
#
# ```
#
# Sample output:
# ```
# Input the salary: 57858
# Your tax bracket is 20%
# Your tax amount due is 11,571.6
# Your net income is 46,286.4
#
# ```
# *Net income is the gross income (total) minus deductions, in this case taxes paid.*

# %%
# Reading the input salary from user
salary = float(input("Input the salary:"))

# My solution starts here --------
# ------------------------------
# the tax amount according to the tax bracket
# I'm using the decimal form to make it easier to calculate
if salary<=30000:
    tax = 0.15
elif salary<=60000:
    tax = 0.20
elif salary<=100000:
    tax = 0.35
elif salary<=130000:
    tax = 0.40
else: #above 130k
    tax = 0.48
#     calculating the amounts
taxAmount = tax*salary
netIncome = salary - taxAmount

# Print the expected output
print("Your tax bracket is ",(tax*100),"%") #multiplied by 100 to make it as % form
print("Your tax amount due is ",taxAmount)
print("You net income is ",netIncome)
# Out:
# Input the salary: 140000
# Your tax bracket is  48.0 %
# Your tax amount due is  67200.0
# You net income is  72800.0

# %% [markdown]
# **Test cases**
#
# - 15% bracket
#
# ```
# Input the salary: 25000
# Your tax bracket is  15.0 %
# Your tax amount due is  3750.0
# You net income is  21250.0
# ```
#
# - 20% bracket
#
# ```
# Input the salary: 57858
# Your tax bracket is  20.0 %
# Your tax amount due is  11571.6
# You net income is  46286.4
# ```
#
# - 35% bracket
#
# ```
# Input the salary: 90000
# Your tax bracket is  35.0 %
# Your tax amount due is  31499.999999999996
# You net income is  58500.0
# ```
#
#
# - 40% bracket
#
# ```
# Input the salary: 110000
# Your tax bracket is  40.0 %
# Your tax amount due is  44000.0
# You net income is  66000.0
# ```
#
# - 48% bracket
#
# ```
# Input the salary: 140000
# Your tax bracket is  48.0 %
# Your tax amount due is  67200.0
# You net income is  72800.0
# ```
